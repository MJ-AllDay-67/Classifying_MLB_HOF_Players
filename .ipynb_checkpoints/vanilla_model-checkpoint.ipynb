# %%
import pandas as pd
pd.options.display.float_format = '{:.3f}'.format
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import itertools

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, precision_recall_curve
from sklearn.metrics import roc_curve, auc
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE, ADASYN
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

# %%
mlb_df = pd.read_pickle('final_df.pkl')
mlb_df.set_index('playerID', inplace=True)
mlb_df.head(25)
# Out:
#               g     ab     r     h   2b  3b   hr      rbi      sb    bb  ...  \
# playerID                                                                 ...
# aaronha01  3298  12364  2174  3771  624  98  755 2297.000 240.000  1402  ...
# abbated01   827   2942   346   748   95  43   11  310.000 138.000   281  ...
# abbotku01   702   2044   273   523  109  23   62  242.000  22.000   133  ...
# abreubo01  2425   8480  1453  2470  574  59  288 1363.000 400.000  1476  ...
# abreujo02   901   3547   483  1038  218  14  179  611.000  10.000   245  ...
# ackledu01   635   2125   261   512   94  18   46  216.000  31.000   194  ...
# adairje01  1165   4019   378  1022  163  19   57  366.000  29.000   208  ...
# adamsbo03  1281   4019   591  1082  188  49   37  303.000  67.000   414  ...
# adamsbu01   576   2003   282   532   96  12   50  249.000  12.000   234  ...
# adamsgl01   661   1617   152   452   79   5   34  225.000   6.000   111  ...
# adamsma01   818   2336   290   609  127   6  116  388.000   4.000   159  ...
# adamssp01  1424   5557   844  1588  249  48    9  394.000 154.000   453  ...
# adcocjo01  1959   6606   823  1832  295  35  336 1122.000  20.000   594  ...
# ageeto01   1129   3912   558   999  170  27  130  433.000 167.000   342  ...
# agnewsa01   563   1537   105   314   41  14    2   98.000  29.000   102  ...
# ahmedni01   613   2014   248   475  102  19   55  231.000  25.000   149  ...
# aikenwi01   774   2492   301   675  125   2  110  415.000   3.000   319  ...
# aldremi01   930   2147   277   565  104   9   41  271.000  19.000   314  ...
# alexada01   662   2450   369   811  164  30   61  459.000  20.000   248  ...
# alfoned01  1506   5385   777  1532  282  18  146  744.000  53.000   596  ...
# alicelu01  1341   3971   551  1031  189  53   47  422.000  81.000   500  ...
# allenbe01  1139   3404   357   815  140  21   73  352.000  13.000   370  ...
# allendi01  1749   6332  1099  1848  320  79  351 1119.000 133.000   894  ...
# allenet01  1281   4418   623  1325  255  45   47  501.000  84.000   223  ...
# alleyge01  1195   3927   442   999  140  44   55  342.000  63.000   300  ...
#
#            k_percentage  bb_percentage    ba  slg_percent   obp   ops   iso  \
# playerID
# aaronha01         9.860          9.930 0.306        0.555 0.374 0.929 0.248
# abbated01           nan            nan   nan          nan   nan   nan   nan
# abbotku01        24.950          6.000 0.252        0.423 0.302 0.726 0.171
# abreubo01        18.207         14.771 0.295        0.483 0.398 0.881 0.188
# abreujo02        20.257          6.400 0.296        0.528 0.352 0.880 0.232
# ackledu01        17.600          7.350 0.235        0.363 0.292 0.655 0.128
# adairje01        11.900          4.967 0.264        0.369 0.300 0.668 0.105
# adamsbo03         9.800          7.850 0.279        0.360 0.331 0.692 0.081
# adamsbu01           nan            nan   nan          nan   nan   nan   nan
# adamsgl01           nan            nan   nan          nan   nan   nan   nan
# adamsma01        20.200          4.600 0.288        0.457 0.321 0.779 0.169
# adamssp01           nan            nan   nan          nan   nan   nan   nan
# adcocjo01        14.060          7.660 0.293        0.515 0.344 0.860 0.222
# ageeto01         20.700          8.340 0.258        0.425 0.325 0.749 0.166
# agnewsa01           nan            nan   nan          nan   nan   nan   nan
# ahmedni01        19.533          7.900 0.251        0.417 0.310 0.727 0.165
# aikenwi01        12.933         11.267 0.275        0.449 0.359 0.809 0.174
# aldremi01           nan            nan   nan          nan   nan   nan   nan
# alexada01           nan            nan   nan          nan   nan   nan   nan
# alfoned01         9.950         10.725 0.290        0.445 0.368 0.813 0.155
# alicelu01        12.000         10.900 0.282        0.389 0.359 0.749 0.107
# allenbe01        12.700          9.600 0.269        0.403 0.334 0.738 0.134
# allendi01        21.740         12.490 0.298        0.554 0.384 0.938 0.256
# allenet01           nan            nan   nan          nan   nan   nan   nan
# alleyge01        13.650          5.900 0.271        0.369 0.315 0.684 0.099
#
#                tb   gidp  inducted_y
# playerID
# aaronha01 316.850 15.350       1.000
# abbated01     nan    nan         nan
# abbotku01 163.000  5.500         nan
# abreubo01 273.571 11.000         nan
# abreujo02 281.286 17.143         nan
# ackledu01 199.500  6.500         nan
# adairje01 207.000 20.333         nan
# adamsbo03 224.000 11.000         nan
# adamsbu01     nan    nan         nan
# adamsgl01     nan    nan         nan
# adamsma01 241.000  9.000         nan
# adamssp01     nan    nan         nan
# adcocjo01 268.000 15.000         nan
# ageeto01  239.000 13.000         nan
# agnewsa01     nan    nan         nan
# ahmedni01 178.333 11.000         nan
# aikenwi01 202.667 17.667         nan
# aldremi01     nan    nan         nan
# alexada01     nan    nan         nan
# alfoned01 236.625 10.250         nan
# alicelu01 187.500 11.500         nan
# allenbe01 231.000  9.000         nan
# allendi01 285.200 11.700         nan
# allenet01     nan    nan         nan
# alleyge01 195.750 13.750         nan
#
# [25 rows x 37 columns]

# %%
mlb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2316 entries, aaronha01 to zuninmi01
# Data columns (total 37 columns):
# g                            2316 non-null int64
# ab                           2316 non-null int64
# r                            2316 non-null int64
# h                            2316 non-null int64
# 2b                           2316 non-null int64
# 3b                           2316 non-null int64
# hr                           2316 non-null int64
# rbi                          2316 non-null float64
# sb                           2316 non-null float64
# bb                           2316 non-null int64
# so                           2316 non-null float64
# asg_mvp                      2316 non-null float64
# baberuth_award               2316 non-null float64
# baseball_magazine_allstar    2316 non-null float64
# comeback_poy                 2316 non-null float64
# gold_glove_award             2316 non-null float64
# hankaaron_award              2316 non-null float64
# hutch_award                  2316 non-null float64
# lougehrig_award              2316 non-null float64
# mvp                          2316 non-null float64
# nlcs_mvp                     2316 non-null float64
# robertoclemente_award        2316 non-null float64
# roy                          2316 non-null float64
# silver_slugger               2316 non-null float64
# tsn_allstar                  2316 non-null float64
# triple_crown                 2316 non-null float64
# ws_mvp                       2316 non-null float64
# k_percentage                 1462 non-null float64
# bb_percentage                1462 non-null float64
# ba                           1462 non-null float64
# slg_percent                  1462 non-null float64
# obp                          1462 non-null float64
# ops                          1462 non-null float64
# iso                          1462 non-null float64
# tb                           1462 non-null float64
# gidp                         1462 non-null float64
# inducted_y                   145 non-null float64
# dtypes: float64(29), int64(8)
# memory usage: 767.6+ KB

# %%
mlb_df.describe()
# Out:
#              g        ab        r        h       2b       3b       hr  \
# count 2316.000  2316.000 2316.000 2316.000 2316.000 2316.000 2316.000
# mean  1256.773  4262.729  587.518 1164.007  205.222   37.378  105.435
# std    534.119  2072.247  347.234  623.185  118.989   31.603  108.079
# min    420.000   789.000   95.000  182.000   26.000    0.000    0.000
# 25%    847.750  2664.750  326.000  688.000  114.000   16.000   29.000
# 50%   1177.000  3908.000  506.500 1046.000  180.000   28.000   72.000
# 75%   1568.000  5433.000  755.250 1494.000  266.000   49.000  140.000
# max   3562.000 14053.000 2295.000 4256.000  792.000  302.000  762.000
#
#            rbi       sb       bb  ...  k_percentage  bb_percentage       ba  \
# count 2316.000 2316.000 2316.000  ...      1462.000       1462.000 1462.000
# mean   545.498   88.886  425.469  ...        14.203          8.837    0.273
# std    352.668  106.721  292.396  ...         5.285          2.925    0.020
# min     56.000    0.000   25.000  ...         2.093          2.150    0.207
# 25%    285.000   22.000  217.000  ...        10.553          6.664    0.260
# 50%    454.500   51.000  351.000  ...        13.658          8.600    0.273
# 75%    706.000  118.000  551.250  ...        17.664         10.786    0.286
# max   2297.000 1406.000 2558.000  ...        33.700         21.660    0.345
#
#        slg_percent      obp      ops      iso       tb     gidp  inducted_y
# count     1462.000 1462.000 1462.000 1462.000 1462.000 1462.000     145.000
# mean         0.426    0.339    0.764    0.153  221.607   11.573       1.000
# std          0.059    0.029    0.080    0.053   38.074    3.833       0.000
# min          0.258    0.239    0.498    0.031   80.000    1.000       1.000
# 25%          0.385    0.318    0.712    0.113  197.113    8.714       1.000
# 50%          0.425    0.338    0.764    0.152  221.909   11.600       1.000
# 75%          0.467    0.358    0.817    0.192  247.429   14.250       1.000
# max          0.631    0.488    1.110    0.323  335.000   25.000       1.000
#
# [8 rows x 37 columns]

# %% [markdown]
# # Fill nulls w/ mean vs. % of each column (Live code switch)

# %% [markdown]
# option 1

# %%
# for column in mlb_df[['k_percentage','bb_percentage','ba','slg_percent','obp','ops','iso','tb','gidp']]: 
#    columnSeriesObj = mlb_df[column]
#    print(column)

# %%
mlb_df.bb_percentage.value_counts(normalize=True)
# Out:
# 6.300    0.008
# 10.400   0.005
# 9.600    0.005
# 8.100    0.005
# 7.500    0.005
#           ...
# 12.033   0.001
# 3.200    0.001
# 7.929    0.001
# 12.144   0.001
# 11.850   0.001
# Name: bb_percentage, Length: 1033, dtype: float64

# %%
# getting unique values and associated probabilites of each value.
options  = mlb_df.k_percentage.value_counts().index.to_list()
percents = mlb_df.k_percentage.value_counts(normalize=True).to_list()

options1  = mlb_df.bb_percentage.value_counts().index.to_list()
percents1 = mlb_df.bb_percentage.value_counts(normalize=True).to_list()

options2  = mlb_df.ba.value_counts().index.to_list()
percents2 = mlb_df.ba.value_counts(normalize=True).to_list()

options3  = mlb_df.slg_percent.value_counts().index.to_list()
percents3 = mlb_df.slg_percent.value_counts(normalize=True).to_list()

options4  = mlb_df.obp.value_counts().index.to_list()
percents4 = mlb_df.obp.value_counts(normalize=True).to_list()

options5  = mlb_df.ops.value_counts().index.to_list()
percents5 = mlb_df.ops.value_counts(normalize=True).to_list()

options6  = mlb_df.iso.value_counts().index.to_list()
percents6 = mlb_df.iso.value_counts(normalize=True).to_list()

options7  = mlb_df.tb.value_counts().index.to_list()
percents7 = mlb_df.tb.value_counts(normalize=True).to_list()

options8  = mlb_df.gidp.value_counts().index.to_list()
percents8 = mlb_df.gidp.value_counts(normalize=True).to_list()

# %%
#using np.random.choice to select
mlb_df['k_percentage'] = mlb_df['k_percentage'].apply(lambda x: np.random.choice(options,1, True,percents)[0] if (not isinstance(x, str)) else x)
mlb_df['bb_percentage'] = mlb_df['bb_percentage'].apply(lambda x: np.random.choice(options1,1, True,percents1)[0] if (not isinstance(x, str)) else x)
mlb_df['ba'] = mlb_df['ba'].apply(lambda x: np.random.choice(options2,1, True,percents2)[0] if (not isinstance(x, str)) else x)
mlb_df['slg_percent'] = mlb_df['slg_percent'].apply(lambda x: np.random.choice(options3,1, True,percents3)[0] if (not isinstance(x, str)) else x)
mlb_df['obp'] = mlb_df['obp'].apply(lambda x: np.random.choice(options4,1, True,percents4)[0] if (not isinstance(x, str)) else x)
mlb_df['ops'] = mlb_df['ops'].apply(lambda x: np.random.choice(options5,1, True,percents5)[0] if (not isinstance(x, str)) else x)
mlb_df['iso'] = mlb_df['iso'].apply(lambda x: np.random.choice(options6,1, True,percents6)[0] if (not isinstance(x, str)) else x)
mlb_df['tb'] = mlb_df['tb'].apply(lambda x: np.random.choice(options7,1, True,percents7)[0] if (not isinstance(x, str)) else x)
mlb_df['gidp'] = mlb_df['gidp'].apply(lambda x: np.random.choice(options8,1, True,percents8)[0] if (not isinstance(x, str)) else x)

# %% [markdown]
# option 2

# %%
#[mlb_df[col].fillna(mlb_df[col].mean(), inplace=True) for col in mlb_df.columns]

# %%
mlb_df.inducted_y.fillna(0, inplace=True)

# %%
mlb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2316 entries, aaronha01 to zuninmi01
# Data columns (total 37 columns):
# g                            2316 non-null int64
# ab                           2316 non-null int64
# r                            2316 non-null int64
# h                            2316 non-null int64
# 2b                           2316 non-null int64
# 3b                           2316 non-null int64
# hr                           2316 non-null int64
# rbi                          2316 non-null float64
# sb                           2316 non-null float64
# bb                           2316 non-null int64
# so                           2316 non-null float64
# asg_mvp                      2316 non-null float64
# baberuth_award               2316 non-null float64
# baseball_magazine_allstar    2316 non-null float64
# comeback_poy                 2316 non-null float64
# gold_glove_award             2316 non-null float64
# hankaaron_award              2316 non-null float64
# hutch_award                  2316 non-null float64
# lougehrig_award              2316 non-null float64
# mvp                          2316 non-null float64
# nlcs_mvp                     2316 non-null float64
# robertoclemente_award        2316 non-null float64
# roy                          2316 non-null float64
# silver_slugger               2316 non-null float64
# tsn_allstar                  2316 non-null float64
# triple_crown                 2316 non-null float64
# ws_mvp                       2316 non-null float64
# k_percentage                 2316 non-null float64
# bb_percentage                2316 non-null float64
# ba                           2316 non-null float64
# slg_percent                  2316 non-null float64
# obp                          2316 non-null float64
# ops                          2316 non-null float64
# iso                          2316 non-null float64
# tb                           2316 non-null float64
# gidp                         2316 non-null float64
# inducted_y                   2316 non-null float64
# dtypes: float64(29), int64(8)
# memory usage: 767.6+ KB

# %%
mlb_df.inducted_y.value_counts()
# Out:
# 0.000    2171
# 1.000     145
# Name: inducted_y, dtype: int64

# %%
# save df at this point to use for models
mlb_df.to_pickle('final_df1.pkl')

# %%
corr = mlb_df.corr()
corr
# Out:
#                                g     ab      r      h     2b     3b     hr  \
# g                          1.000  0.978  0.923  0.957  0.904  0.566  0.656
# ab                         0.978  1.000  0.953  0.988  0.934  0.613  0.653
# r                          0.923  0.953  1.000  0.964  0.928  0.641  0.705
# h                          0.957  0.988  0.964  1.000  0.949  0.657  0.637
# 2b                         0.904  0.934  0.928  0.949  1.000  0.546  0.702
# 3b                         0.566  0.613  0.641  0.657  0.546  1.000  0.106
# hr                         0.656  0.653  0.705  0.637  0.702  0.106  1.000
# rbi                        0.876  0.891  0.900  0.900  0.918  0.479  0.863
# sb                         0.447  0.485  0.536  0.488  0.380  0.580  0.061
# bb                         0.823  0.807  0.878  0.799  0.782  0.440  0.708
# so                         0.668  0.656  0.655  0.598  0.656  0.108  0.823
# asg_mvp                    0.230  0.237  0.231  0.237  0.214  0.072  0.236
# baberuth_award             0.132  0.129  0.123  0.122  0.105  0.026  0.137
# baseball_magazine_allstar  0.257  0.273  0.342  0.337  0.304  0.516  0.087
# comeback_poy               0.039  0.045  0.054  0.046  0.073 -0.036  0.104
# gold_glove_award           0.390  0.395  0.360  0.375  0.360  0.122  0.314
# hankaaron_award            0.144  0.150  0.202  0.158  0.188 -0.024  0.288
# hutch_award                0.167  0.165  0.163  0.167  0.167  0.040  0.147
# lougehrig_award            0.257  0.268  0.262  0.266  0.236  0.114  0.232
# mvp                        0.346  0.353  0.432  0.380  0.369  0.216  0.454
# nlcs_mvp                   0.074  0.074  0.063  0.072  0.084 -0.018  0.083
# robertoclemente_award      0.254  0.263  0.268  0.260  0.259  0.079  0.255
# roy                        0.158  0.173  0.181  0.172  0.156  0.026  0.204
# silver_slugger             0.387  0.409  0.441  0.416  0.462  0.023  0.529
# tsn_allstar                0.538  0.551  0.601  0.574  0.553  0.258  0.596
# triple_crown               0.145  0.144  0.208  0.183  0.188  0.165  0.178
# ws_mvp                     0.145  0.145  0.142  0.139  0.141  0.012  0.162
# k_percentage              -0.008 -0.004 -0.001 -0.003  0.003 -0.012 -0.026
# bb_percentage             -0.032 -0.030 -0.031 -0.029 -0.023 -0.027 -0.017
# ba                         0.013  0.014  0.008  0.008  0.017  0.002  0.023
# slg_percent               -0.008 -0.019 -0.027 -0.018 -0.004 -0.037  0.002
# obp                       -0.014 -0.018 -0.007 -0.013 -0.010  0.009 -0.004
# ops                       -0.000  0.003  0.007  0.005  0.004  0.009 -0.012
# iso                        0.004  0.004  0.004  0.008  0.002  0.002  0.002
# tb                         0.011  0.009  0.006  0.006  0.007 -0.006  0.011
# gidp                      -0.001  0.003  0.008 -0.001  0.007 -0.020  0.021
# inducted_y                 0.428  0.448  0.511  0.495  0.448  0.472  0.316
#
#                              rbi     sb     bb  ...  k_percentage  \
# g                          0.876  0.447  0.823  ...        -0.008
# ab                         0.891  0.485  0.807  ...        -0.004
# r                          0.900  0.536  0.878  ...        -0.001
# h                          0.900  0.488  0.799  ...        -0.003
# 2b                         0.918  0.380  0.782  ...         0.003
# 3b                         0.479  0.580  0.440  ...        -0.012
# hr                         0.863  0.061  0.708  ...        -0.026
# rbi                        1.000  0.259  0.812  ...        -0.018
# sb                         0.259  1.000  0.373  ...         0.008
# bb                         0.812  0.373  1.000  ...         0.014
# so                         0.709  0.249  0.646  ...        -0.016
# asg_mvp                    0.234  0.124  0.189  ...         0.017
# baberuth_award             0.130  0.048  0.102  ...         0.005
# baseball_magazine_allstar  0.321  0.178  0.271  ...        -0.031
# comeback_poy               0.075 -0.012  0.063  ...         0.028
# gold_glove_award           0.335  0.195  0.292  ...         0.002
# hankaaron_award            0.222  0.057  0.216  ...         0.023
# hutch_award                0.158  0.071  0.164  ...        -0.020
# lougehrig_award            0.250  0.081  0.239  ...        -0.022
# mvp                        0.451  0.155  0.422  ...        -0.010
# nlcs_mvp                   0.082  0.001  0.042  ...        -0.023
# robertoclemente_award      0.255  0.138  0.241  ...        -0.014
# roy                        0.173  0.075  0.162  ...         0.019
# silver_slugger             0.479  0.162  0.390  ...        -0.012
# tsn_allstar                0.627  0.170  0.557  ...         0.005
# triple_crown               0.219  0.053  0.202  ...        -0.030
# ws_mvp                     0.152  0.013  0.141  ...        -0.011
# k_percentage              -0.018  0.008  0.014  ...         1.000
# bb_percentage             -0.028 -0.021 -0.030  ...         0.003
# ba                         0.015 -0.002  0.010  ...        -0.037
# slg_percent               -0.002 -0.057 -0.008  ...         0.013
# obp                       -0.005 -0.017 -0.006  ...        -0.009
# ops                       -0.004  0.018 -0.004  ...         0.014
# iso                        0.001 -0.016 -0.004  ...        -0.011
# tb                         0.010 -0.005  0.013  ...         0.008
# gidp                       0.007  0.018  0.010  ...         0.008
# inducted_y                 0.477  0.261  0.432  ...        -0.018
#
#                            bb_percentage     ba  slg_percent    obp    ops  \
# g                                 -0.032  0.013       -0.008 -0.014 -0.000
# ab                                -0.030  0.014       -0.019 -0.018  0.003
# r                                 -0.031  0.008       -0.027 -0.007  0.007
# h                                 -0.029  0.008       -0.018 -0.013  0.005
# 2b                                -0.023  0.017       -0.004 -0.010  0.004
# 3b                                -0.027  0.002       -0.037  0.009  0.009
# hr                                -0.017  0.023        0.002 -0.004 -0.012
# rbi                               -0.028  0.015       -0.002 -0.005 -0.004
# sb                                -0.021 -0.002       -0.057 -0.017  0.018
# bb                                -0.030  0.010       -0.008 -0.006 -0.004
# so                                -0.013  0.029        0.004 -0.023 -0.014
# asg_mvp                            0.010 -0.011       -0.015  0.006 -0.012
# baberuth_award                    -0.010 -0.036       -0.004  0.030 -0.023
# baseball_magazine_allstar          0.004 -0.011        0.015  0.011  0.009
# comeback_poy                      -0.017  0.002        0.015  0.040  0.003
# gold_glove_award                  -0.004 -0.020       -0.003  0.053  0.022
# hankaaron_award                    0.017  0.002        0.015  0.010  0.012
# hutch_award                       -0.021  0.003       -0.013  0.020 -0.022
# lougehrig_award                   -0.004  0.037        0.013  0.018  0.035
# mvp                                0.012  0.005       -0.000 -0.007 -0.002
# nlcs_mvp                           0.029  0.006       -0.021 -0.015 -0.029
# robertoclemente_award              0.022  0.026       -0.019 -0.005 -0.005
# roy                                0.002  0.028        0.013 -0.000 -0.042
# silver_slugger                    -0.026 -0.006        0.000 -0.004  0.018
# tsn_allstar                       -0.022  0.002       -0.009  0.011  0.025
# triple_crown                       0.017 -0.023       -0.001 -0.017 -0.020
# ws_mvp                            -0.014  0.011       -0.016  0.004 -0.029
# k_percentage                       0.003 -0.037        0.013 -0.009  0.014
# bb_percentage                      1.000  0.007       -0.033 -0.016 -0.010
# ba                                 0.007  1.000       -0.018 -0.012  0.021
# slg_percent                       -0.033 -0.018        1.000  0.020  0.000
# obp                               -0.016 -0.012        0.020  1.000 -0.010
# ops                               -0.010  0.021        0.000 -0.010  1.000
# iso                               -0.015  0.021        0.033 -0.007 -0.022
# tb                                -0.026  0.010        0.022 -0.003 -0.013
# gidp                               0.008 -0.016        0.022  0.015  0.008
# inducted_y                         0.002 -0.023       -0.001  0.034 -0.003
#
#                              iso     tb   gidp  inducted_y
# g                          0.004  0.011 -0.001       0.428
# ab                         0.004  0.009  0.003       0.448
# r                          0.004  0.006  0.008       0.511
# h                          0.008  0.006 -0.001       0.495
# 2b                         0.002  0.007  0.007       0.448
# 3b                         0.002 -0.006 -0.020       0.472
# hr                         0.002  0.011  0.021       0.316
# rbi                        0.001  0.010  0.007       0.477
# sb                        -0.016 -0.005  0.018       0.261
# bb                        -0.004  0.013  0.010       0.432
# so                         0.010  0.022  0.031       0.158
# asg_mvp                    0.013  0.008 -0.006       0.173
# baberuth_award            -0.017  0.002  0.033       0.151
# baseball_magazine_allstar -0.025 -0.019 -0.019       0.515
# comeback_poy               0.023  0.034 -0.013       0.003
# gold_glove_award           0.052 -0.002  0.020       0.207
# hankaaron_award           -0.001  0.017  0.045      -0.003
# hutch_award               -0.010  0.020 -0.004       0.141
# lougehrig_award            0.029  0.022  0.007       0.236
# mvp                        0.000 -0.001  0.017       0.391
# nlcs_mvp                   0.012 -0.016  0.017       0.018
# robertoclemente_award      0.000  0.054  0.048       0.180
# roy                       -0.001  0.024  0.004       0.093
# silver_slugger            -0.006  0.019  0.030       0.203
# tsn_allstar                0.016  0.014  0.032       0.555
# triple_crown              -0.015 -0.017  0.002       0.246
# ws_mvp                    -0.005  0.013  0.042       0.117
# k_percentage              -0.011  0.008  0.008      -0.018
# bb_percentage             -0.015 -0.026  0.008       0.002
# ba                         0.021  0.010 -0.016      -0.023
# slg_percent                0.033  0.022  0.022      -0.001
# obp                       -0.007 -0.003  0.015       0.034
# ops                       -0.022 -0.013  0.008      -0.003
# iso                        1.000 -0.010 -0.017       0.032
# tb                        -0.010  1.000 -0.009      -0.015
# gidp                      -0.017 -0.009  1.000      -0.031
# inducted_y                 0.032 -0.015 -0.031       1.000
#
# [37 rows x 37 columns]

# %%
fig, ax = plt.subplots(figsize=(24,14))
sns.heatmap(corr, annot=True, cmap='Blues')

# %% [markdown]
# # Model #1: Vanilla Model

# %% [markdown]
# starting off with a decision tree as my baseline model because as you can see from above, I have multicolinearity between a few of my predictors so using a Decision Tree is best because multicolinearity does not have an affect on this type of model.

# %%
y = mlb_df['inducted_y']
X = mlb_df.drop(columns='inducted_y')

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y, random_state=42)

# %%
# instantiate and fit
dt_clf = DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=42)
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
test_preds = dt_clf.predict(X_test)

# confusion matrix and classification report
def print_metrics(labels, preds):
    print(confusion_matrix(labels, preds))
    print(classification_report(labels, preds))
    print('Accuracy score: ',accuracy_score(labels, preds))
    print('Recall score: ',recall_score(labels, preds))
    print('Precision score: ',precision_score(labels, preds))
    print('F1 score: ',f1_score(labels, preds))
    
print_metrics(y_test, test_preds)
# Out:
# [[638  13]
#  [ 17  27]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.98       651
#          1.0       0.68      0.61      0.64        44
#
#     accuracy                           0.96       695
#    macro avg       0.82      0.80      0.81       695
# weighted avg       0.96      0.96      0.96       695
#
# Accuracy score:  0.9568345323741008
# Recall score:  0.6136363636363636
# Precision score:  0.675
# F1 score:  0.6428571428571429

# %%
# plotting confusion matrix
plot_confusion_matrix(dt_clf, X_test, y_test, cmap="Blues")
plt.show()

# %% [markdown]
# - 95% accuracy is good, but still 18 FN is pretty high when considering there were only 44 HOFers in this test data
# - Accuracy is also susceptible to a false high accuracy if there is high class imbalance, which I have. After further evaluation I will try running model using SMOTE, which creates artificial data for the minority class, which will rid the imbalance

# %%
# plotting feature importances
def plot_feature_importances(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(8,12))
    plt.barh(range(n_features), model.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), X_train.columns.values) 
    plt.xlabel('Feature Importances')
    plt.ylabel('Feature')

plot_feature_importances(dt_clf)
plt.tight_layout()
plt.savefig('./images/feature_importances_vanilla.png')

# %% [markdown]
# As you can see, the model values being named to the All-Star team as the most important predictor. This is not surprising because you become a HOF player by dominating over many years of your playing career. If you are doing so, you are likely to be named to the All-Star team more than the average player on a year-by-year basis.
#
# What is surprising is that I would have expected Hits and HRs to be of more importance because looking at the top 20 players in each category, the majority of them are HOFers.

# %%
# false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(false_positive_rate, true_positive_rate)
# print('Accuracy is: {0}'.format(acc))

# %% [markdown]
# # Model #2: SMOTE

# %% [markdown]
# Not only do I have class imbalance, but also have a limited number of positives in the target class. Using SMOTE, we can artifically create more training data to better balance the data. Let's see how this affects our model

# %%
# positives before SMOTE
y_train.value_counts()
# Out:
# 0.000    1520
# 1.000     101
# Name: inducted_y, dtype: int64

# %%
# positives after resampling with SMOTE
X_train_resampled, y_train_resampled = SMOTE().fit_resample(X_train, y_train)
print(pd.Series(y_train_resampled).value_counts())
# Out:
# 1.000    1520
# 0.000    1520
# Name: inducted_y, dtype: int64

# %%
# run another DT on resampled training data - artificially created more HOFers using SMOTE
clf_dt2 = DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=42)

# fit the model
clf_dt2.fit(X_train_resampled, y_train_resampled)

# prediction for training data
train_pred_smote = clf_dt2.predict(X_train_resampled)

# print metrics
print_metrics(y_train_resampled, train_pred_smote)
# Out:
# [[1431   89]
#  [  11 1509]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.94      0.97      1520
#          1.0       0.94      0.99      0.97      1520
#
#     accuracy                           0.97      3040
#    macro avg       0.97      0.97      0.97      3040
# weighted avg       0.97      0.97      0.97      3040
#
# Accuracy score:  0.9671052631578947
# Recall score:  0.9927631578947368
# Precision score:  0.9443053817271589
# F1 score:  0.967928159076331

# %% [markdown]
# Training data is acting as a pretty effective training set after incorporating SMOTE. Let's see how the model now performs on the test data.

# %%
# prediction for testing data
test_pred = clf_dt2.predict(X_test)

# print metrics
print_metrics(y_test, test_pred)
# Out:
# [[595  56]
#  [ 13  31]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.91      0.95       651
#          1.0       0.36      0.70      0.47        44
#
#     accuracy                           0.90       695
#    macro avg       0.67      0.81      0.71       695
# weighted avg       0.94      0.90      0.92       695
#
# Accuracy score:  0.9007194244604316
# Recall score:  0.7045454545454546
# Precision score:  0.3563218390804598
# F1 score:  0.47328244274809167

# %% [markdown]
# - Recall increased significantly from 60% to now almost 80%.
# - Precision decreased from 65% to 42%.
# - Accuracy and F1 decreased slightly.

# %% [markdown]
# After 2nd round of EDA, I decided to remove the following non-HOFers due to them being banned by the MLB for various reasons i.e. steroid use. This should reduce confusion for the model as these players have some of the best stats in the history of the game, but are not in the HOF.

# %%
mlb_df.inducted_y.value_counts()
# Out:
# 0.000    2171
# 1.000     145
# Name: inducted_y, dtype: int64

# %%
mlb_df.drop(['rosepe01','rodrial01','bondsba01','sosasa01','mcgwima01','ramirma02',
             'palmera01','ortizda01'], axis=0, inplace=True)

# %%
mlb_df.inducted_y.value_counts()
# Out:
# 0.000    2163
# 1.000     145
# Name: inducted_y, dtype: int64

# %%
mlb_df.to_pickle('final_df2_removed_banned_players.pkl')

# %% [markdown]
# # Model #3: DT w/ Refined DB and Balanced class_weight

# %%
# instantiate and fit
dt_clf3 = DecisionTreeClassifier(criterion='gini', max_depth=5, class_weight='balanced', random_state=42)
dt_clf3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5, random_state=42)

# %%
# predict on test data
test_preds = dt_clf3.predict(X_test)

# print metrics on test data
print_metrics(y_test, test_preds)
# Out:
# [[615  36]
#  [ 16  28]]
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.96       651
#          1.0       0.44      0.64      0.52        44
#
#     accuracy                           0.93       695
#    macro avg       0.71      0.79      0.74       695
# weighted avg       0.94      0.93      0.93       695
#
# Accuracy score:  0.9251798561151079
# Recall score:  0.6363636363636364
# Precision score:  0.4375
# F1 score:  0.5185185185185185

# %% [markdown]
# Accuracy and recall actually decreased some, while Precision and F1 increased

# %% [markdown]
# checking for multicolinearity with The Variance Inflation

# %%
outcome = 'inducted_Y'
x_cols = list(mlb_df.columns)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = mlb_df[x_cols]
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
list(zip(x_cols, vif))
# Out:
# [('g', 220.33838738208092),
#  ('ab', 702.4264104836755),
#  ('r', 258.24529469288365),
#  ('h', 716.1601728627855),
#  ('2b', 71.82071536844961),
#  ('3b', 12.05911831120753),
#  ('hr', 59.064061514494284),
#  ('rbi', 150.37356916377325),
#  ('sb', 5.178729442603921),
#  ('bb', 40.48352733162004),
#  ('so', 38.866253448282194),
#  ('asg_mvp', 1.2075645387901923),
#  ('baberuth_award', 1.417641416159652),
#  ('baseball_magazine_allstar', 2.2007084054506145),
#  ('comeback_poy', 1.0426323014037182),
#  ('gold_glove_award', 1.5711859778820072),
#  ('hankaaron_award', 1.5207617636328667),
#  ('hutch_award', 1.1490247300447995),
#  ('lougehrig_award', 1.365916759355341),
#  ('mvp', 2.0954354755622213),
#  ('nlcs_mvp', 1.0518068619575944),
#  ('robertoclemente_award', 1.3264286762247275),
#  ('roy', 1.142574217511013),
#  ('silver_slugger', 2.5135093258002814),
#  ('tsn_allstar', 3.6441745397692236),
#  ('triple_crown', 1.2871506563539212),
#  ('ws_mvp', 1.4281115789108303),
#  ('k_percentage', 40.76871810973261),
#  ('bb_percentage', 465.7054300780311),
#  ('ba', 1678451.9506124924),
#  ('slg_percent', 5726953.764163095),
#  ('obp', 2811444.3265331406),
#  ('ops', 14369726.171886016),
#  ('iso', 564413.2698197329),
#  ('tb', 257.06166946178587),
#  ('gidp', 23.324940888930787),
#  ('inducted_y', 1.691272230890889)]
